# %%
import os
from get_data import download_s3_folder
download_s3_folder('anyoneai-datasets', 'nasdaq_annual_reports', os.path.join(os.getcwd(),'dataset'))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 from get_data import download_s3_folder
# ----> 2 download_s3_folder('anyoneai-datasets', 'nasdaq_annual_reports', './dataset')
#
# File ~/Documents/anyoneai/financial-advisor-chatbot/get_data.py:20, in download_s3_folder(bucket_name, s3_folder, local_dir)
#      12 """
#      13 Download the contents of a folder directory
#      14 Args:
#    (...)
#      17     local_dir: a relative or absolute directory path in the local file system
#      18 """
#      19 bucket = s3.Bucket(bucket_name)
# ---> 20 for obj in bucket.objects.filter(Prefix=s3_folder):
#      21     target = (
#      22         obj.key
#      23         if local_dir is None
#      24         else os.path.join(local_dir, os.path.relpath(obj.key, s3_folder))
#      25     )
#      26     if not os.path.exists(os.path.dirname(target)):
#
# ...
